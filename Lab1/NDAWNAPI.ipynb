# %%
import requests
import json
import pprint
import zipfile

url = "https://ndawn.ndsu.nodak.edu/get-table.html?station=161&variable=wdavt&ttype=weekly&quick_pick=1_w&begin_date=2021-09-29&count=1"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>NDAWN Tables - Weekly Weather Data</title>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#    ga('create', 'UA-78735593-1', 'auto');
#    ga('send', 'pageview');
#   </script>
#   <link href="/ndawn-min.css" rel="stylesheet" type="text/css">
#   <script defer src="/jquery.min.js"></script>
#   <script defer src="/ndawn-min.js"></script>
#   <script async src='https://www.google-analytics.com/analytics.js'></script>
#  </head>
#  <body>
#   <div class="printhide" id="page-top">
#    <div id="page-top-row">
# ...
